# %%
# %load_ext autoreload
# %autoreload 2
from notebook import *
# if get something about NUMEXPR_MAX_THREADS being set incorrectly, don't worry.  It's not a problem.
# Out:
# <style>h1 {font-size: 2vw;} h2 {font-size: 1.5vw;} p {font-size: 1.4vw;} div.prompt, code, output, prompt, kbd, pre, samp {font-family: 'SF Mono', 'Courier New', Courier, monospace, sans-serif !important;font-size: 1.4vw !important;}</style>

# %% [markdown]
# # Branch and branch predictions

# %% [markdown]
# ## Why do we have "branches" in code?
#
# Consider the following code snippet, how does the compiler translate to instructions?

# %%
render_code("branch.c", show="main")
# Out:
# // branch.c:26-45 (20 lines)
# int main(int argc, char **argv)
# {
#     FILE *fin;
#     int size,i;
#     uint64_t *data;
#     uint64_t threshold;
#     fin = fopen(argv[1],"r");
#     size = atoi(argv[2]);
#     threshold = atoi(argv[3]);
#     data = (uint64_t *)malloc(sizeof(uint64_t)*size);
#     fread(data, sizeof(uint64_t),size,fin);
#     for(i=0;i<size;i++)
#     {
#         if (data[i] % 2 != 0)
#             call_when_true(&data[i]);
#         else
#             call_when_false(&data[i]);
#     }
#     return 0;
# }

# %%
! gcc -S -O0 branch.c
render_code("branch.s", show=[".L12:",".LFE9:"])
# Out:
# branch.c:17:1: warning: ‘O0’ attribute directive ignored [-Wattributes]
#    17 | {
#       | ^
# // branch.s:169-206 (38 lines)
# .L12:
# 	movl	-32(%rbp), %eax
# 	cltq
# 	leaq	0(,%rax,8), %rdx
# 	movq	-8(%rbp), %rax
# 	addq	%rdx, %rax
# 	movq	(%rax), %rax
# 	andl	$1, %eax
# 	testq	%rax, %rax
# 	je	.L10
# 	movl	-32(%rbp), %eax
# 	cltq
# 	leaq	0(,%rax,8), %rdx
# 	movq	-8(%rbp), %rax
# 	addq	%rdx, %rax
# 	movq	%rax, %rdi
# 	call	call_when_true
# 	jmp	.L11
# .L10:
# 	movl	-32(%rbp), %eax
# 	cltq
# 	leaq	0(,%rax,8), %rdx
# 	movq	-8(%rbp), %rax
# 	addq	%rdx, %rax
# 	movq	%rax, %rdi
# 	call	call_when_false
# .L11:
# 	addl	$1, -32(%rbp)
# .L9:
# 	movl	-32(%rbp), %eax
# 	cmpl	-28(%rbp), %eax
# 	jl	.L12
# 	movl	$0, %eax
# 	leave
# 	.cfi_def_cfa 7, 8
# 	ret
# 	.cfi_endproc
# .LFE9:

# %%
! gcc -S -O2 loop.c
render_code("loop.s", show=["loop1","LFE24"])
# Out:
# // loop.s:52-69 (18 lines)
# 	.globl	loop1
# 	.type	loop1, @function
# loop1:
# .LFB24:
# 	.cfi_startproc
# 	endbr64
# 	leaq	40(%rdi), %rdx
# 	xorl	%eax, %eax
# 	.p2align 4,,10
# 	.p2align 3
# .L16:
# 	addl	(%rdi), %eax
# 	addq	$4, %rdi
# 	cmpq	%rdx, %rdi
# 	jne	.L16
# 	ret
# 	.cfi_endproc
# .LFE24:

# %% [markdown]
# ## Sorting and branch miss rates
#
# Do you remember this?

# %%
compare([do_render_code("arraySort.cpp",show=["//START","//END"]),do_render_code("calculate_sum.c", show="calculate_sum")])
# Out:
#             <style>
#         .side-by-side {
#             display: flex;
#             align-items: stretch;
#         }
#         .side-by-side-pane {
#             margin-right:1em;
#             border-right-style: solid;
#             border-right-color: black;
#             border-right-width: 1px;
#             flex: 1;
#         }
#         </style>
#         <div class="side-by-side"> <div class='side-by-side-pane'><style>pre { line-height: 125%; }
# td.linenos .normal { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# .output_html .hll { background-color: #ffffcc }
# .output_html { background: #f8f8f8; }
# .output_html .c { color: #3D7B7B; font-style: italic } /* Comment */
# .output_html .err { border: 1px solid #FF0000 } /* Error */
# .output_html .k { color: #008000; font-weight: bold } /* Keyword */
# .output_html .o { color: #666666 } /* Operator */
# .output_html .ch { color: #3D7B7B; font-style: italic } /* Comment.Hashbang */
# .output_html .cm { color: #3D7B7B; font-style: italic } /* Comment.Multiline */
# .output_html .cp { color: #9C6500 } /* Comment.Preproc */
# .output_html .cpf { color: #3D7B7B; font-style: italic } /* Comment.PreprocFile */
# .output_html .c1 { color: #3D7B7B; font-style: italic } /* Comment.Single */
# .output_html .cs { color: #3D7B7B; font-style: italic } /* Comment.Special */
# .output_html .gd { color: #A00000 } /* Generic.Deleted */
# .output_html .ge { font-style: italic } /* Generic.Emph */
# .output_html .ges { font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# .output_html .gr { color: #E40000 } /* Generic.Error */
# .output_html .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .output_html .gi { color: #008400 } /* Generic.Inserted */
# .output_html .go { color: #717171 } /* Generic.Output */
# .output_html .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# .output_html .gs { font-weight: bold } /* Generic.Strong */
# .output_html .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .output_html .gt { color: #0044DD } /* Generic.Traceback */
# .output_html .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# .output_html .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# .output_html .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# .output_html .kp { color: #008000 } /* Keyword.Pseudo */
# .output_html .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# .output_html .kt { color: #B00040 } /* Keyword.Type */
# .output_html .m { color: #666666 } /* Literal.Number */
# .output_html .s { color: #BA2121 } /* Literal.String */
# .output_html .na { color: #687822 } /* Name.Attribute */
# .output_html .nb { color: #008000 } /* Name.Builtin */
# .output_html .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# .output_html .no { color: #880000 } /* Name.Constant */
# .output_html .nd { color: #AA22FF } /* Name.Decorator */
# .output_html .ni { color: #717171; font-weight: bold } /* Name.Entity */
# .output_html .ne { color: #CB3F38; font-weight: bold } /* Name.Exception */
# .output_html .nf { color: #0000FF } /* Name.Function */
# .output_html .nl { color: #767600 } /* Name.Label */
# .output_html .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# .output_html .nt { color: #008000; font-weight: bold } /* Name.Tag */
# .output_html .nv { color: #19177C } /* Name.Variable */
# .output_html .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# .output_html .w { color: #bbbbbb } /* Text.Whitespace */
# .output_html .mb { color: #666666 } /* Literal.Number.Bin */
# .output_html .mf { color: #666666 } /* Literal.Number.Float */
# .output_html .mh { color: #666666 } /* Literal.Number.Hex */
# .output_html .mi { color: #666666 } /* Literal.Number.Integer */
# .output_html .mo { color: #666666 } /* Literal.Number.Oct */
# .output_html .sa { color: #BA2121 } /* Literal.String.Affix */
# .output_html .sb { color: #BA2121 } /* Literal.String.Backtick */
# .output_html .sc { color: #BA2121 } /* Literal.String.Char */
# .output_html .dl { color: #BA2121 } /* Literal.String.Delimiter */
# .output_html .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# .output_html .s2 { color: #BA2121 } /* Literal.String.Double */
# .output_html .se { color: #AA5D1F; font-weight: bold } /* Literal.String.Escape */
# .output_html .sh { color: #BA2121 } /* Literal.String.Heredoc */
# .output_html .si { color: #A45A77; font-weight: bold } /* Literal.String.Interpol */
# .output_html .sx { color: #008000 } /* Literal.String.Other */
# .output_html .sr { color: #A45A77 } /* Literal.String.Regex */
# .output_html .s1 { color: #BA2121 } /* Literal.String.Single */
# .output_html .ss { color: #19177C } /* Literal.String.Symbol */
# .output_html .bp { color: #008000 } /* Name.Builtin.Pseudo */
# .output_html .fm { color: #0000FF } /* Name.Function.Magic */
# .output_html .vc { color: #19177C } /* Name.Variable.Class */
# .output_html .vg { color: #19177C } /* Name.Variable.Global */
# .output_html .vi { color: #19177C } /* Name.Variable.Instance */
# .output_html .vm { color: #19177C } /* Name.Variable.Magic */
# .output_html .il { color: #666666 } /* Literal.Number.Integer.Long */</style><div class="highlight"><pre><span></span><span class="c1">// arraySort.cpp:40-50 (11 lines)</span>
# <span class="w">    </span><span class="c1">//START</span>
# <span class="w">    </span><span class="k">if</span><span class="p">(</span><span class="n">option</span><span class="p">)</span>
# <span class="w">        </span><span class="n">std</span><span class="o">::</span><span class="n">sort</span><span class="p">(</span><span class="n">data</span><span class="p">,</span><span class="w"> </span><span class="n">data</span><span class="w"> </span><span class="o">+</span><span class="w"> </span><span class="n">arraySize</span><span class="p">);</span>
# <span class="cp">#ifndef COUNT_SORTING</span>
# <span class="w">    </span><span class="n">perfstats_init</span><span class="p">();</span>
# <span class="w">    </span><span class="n">perfstats_enable</span><span class="p">(</span><span class="mi">1</span><span class="p">);</span>
# <span class="cp">#endif</span>
# <span class="w">    </span><span class="k">for</span><span class="w"> </span><span class="p">(</span><span class="kt">unsigned</span><span class="w"> </span><span class="n">i</span><span class="w"> </span><span class="o">=</span><span class="w"> </span><span class="mi">0</span><span class="p">;</span><span class="w"> </span><span class="n">i</span><span class="w"> </span><span class="o">&lt;</span><span class="w"> </span><span class="n">iterations</span><span class="p">;</span><span class="w"> </span><span class="o">++</span><span class="n">i</span><span class="p">)</span><span class="w"> </span><span class="p">{</span>
# <span class="w">        </span><span class="n">sum</span><span class="w"> </span><span class="o">+=</span><span class="w"> </span><span class="n">calculate_sum</span><span class="p">(</span><span class="n">data</span><span class="p">,</span><span class="w"> </span><span class="n">arraySize</span><span class="p">,</span><span class="w"> </span><span class="n">std</span><span class="o">::</span><span class="n">rand</span><span class="p">());</span>
# <span class="w">    </span><span class="p">}</span>
# <span class="w">    </span><span class="c1">//END</span>
# </pre></div>
# </div><div class='side-by-side-pane'><style>pre { line-height: 125%; }
# td.linenos .normal { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-r

# %%
! lscpu | grep 'Model name'
# Out:
# Model name:                           Intel(R) Core(TM) i7-14700K

# %%
! make clean; make EXTRA_OPTS=-DCOUNT_SORTING; sleep 2
! echo "size,iterations,sorted,IC,Cycles,CPI,CT,ET,L1_dcache_miss_rate,L1_dcache_misses,L1_dcache_accesses,branches,branch_misses" > stats.csv
! echo -n "131072,1000,0," >> stats.csv
! taskset -c 8 ./arraySort 131072 1000 0
! echo -n "131072,1000,1," >> stats.csv
! taskset -c 8 ./arraySort 131072 1000 1
# Out:
# rm -f madd arraySort *.o
# gcc -g -DHAVE_LINUX_PERF_EVENT_H -O0 -DCOUNT_SORTING -I/nfshome/htseng/courses/CS203/demo/branch  -o calculate_sum.o -c calculate_sum.c
# gcc -g -DHAVE_LINUX_PERF_EVENT_H -O3 -DCOUNT_SORTING -I/nfshome/htseng/courses/CS203/demo/branch  -o perfstats.o -c perfstats.c
# perfstats.c: In function ‘change_cpufrequnecy’:
# perfstats.c:115:11: warning: implicit declaration of function ‘sched_getcpu’; did you mean ‘SYS_getcpu’? [-Wimplicit-function-declaration]
#   115 |     cpu = sched_getcpu();
#       |           ^~~~~~~~~~~~
#       |           SYS_getcpu
# g++ -O3 -DHAVE_LINUX_PERF_EVENT_H -DCOUNT_SORTING arraySort.cpp perfstats.o calculate_sum.o -o arraySort
# arraySort.cpp: In function ‘int main(int, char**)’:
# arraySort.cpp:53:22: warning: zero-length gnu_printf format string [-Wformat-zero-length]
#    53 |     sprintf(preamble,"");
#       |                      ^~
# g++ -g -DHAVE_LINUX_PERF_EVENT_H -O0 -DCOUNT_SORTING -I/nfshome/htseng/courses/CS203/demo/branch  -o bst.o -c bst.cpp
# g++ -O3 -DHAVE_LINUX_PERF_EVENT_H -DCOUNT_SORTING bstSearch.cpp perfstats.o bst.o -o bstSearch
# bstSearch.cpp: In function ‘int main(int, char**)’:
# bstSearch.cpp:54:22: warning: zero-length gnu_printf format string [-Wformat-zero-length]
#    54 |     sprintf(preamble,"");
#       |                      ^~
# sum = 64494148
# sum = 64494148

# %%
display_df_mono(render_csv("stats.csv"))
# Out:
# <style type="text/css">
# #T_a9ee3_row0_col0, #T_a9ee3_row0_col1, #T_a9ee3_row0_col2, #T_a9ee3_row0_col3, #T_a9ee3_row0_col4, #T_a9ee3_row0_col5, #T_a9ee3_row0_col6, #T_a9ee3_row0_col7, #T_a9ee3_row0_col8, #T_a9ee3_row0_col9, #T_a9ee3_row0_col10, #T_a9ee3_row0_col11, #T_a9ee3_row0_col12, #T_a9ee3_row0_col13, #T_a9ee3_row1_col0, #T_a9ee3_row1_col1, #T_a9ee3_row1_col2, #T_a9ee3_row1_col3, #T_a9ee3_row1_col4, #T_a9ee3_row1_col5, #T_a9ee3_row1_col6, #T_a9ee3_row1_col7, #T_a9ee3_row1_col8, #T_a9ee3_row1_col9, #T_a9ee3_row1_col10, #T_a9ee3_row1_col11, #T_a9ee3_row1_col12, #T_a9ee3_row1_col13 {
#   font-family: SF Mono;
#   font-size: 1.4vw;
# }
# </style>
# <table id="T_a9ee3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a9ee3_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_a9ee3_level0_col1" class="col_heading level0 col1" >size</th>
#       <th id="T_a9ee3_level0_col2" class="col_heading level0 col2" >iterations</th>
#       <th id="T_a9ee3_level0_col3" class="col_heading level0 col3" >sorted</th>
#       <th id="T_a9ee3_level0_col4" class="col_heading level0 col4" >IC</th>
#       <th id="T_a9ee3_level0_col5" class="col_heading level0 col5" >Cycles</th>
#       <th id="T_a9ee3_level0_col6" class="col_heading level0 col6" >CPI</th>
#       <th id="T_a9ee3_level0_col7" class="col_heading level0 col7" >CT</th>
#       <th id="T_a9ee3_level0_col8" class="col_heading level0 col8" >ET</th>
#       <th id="T_a9ee3_level0_col9" class="col_heading level0 col9" >L1_dcache_miss_rate</th>
#       <th id="T_a9ee3_level0_col10" class="col_heading level0 col10" >L1_dcache_misses</th>
#       <th id="T_a9ee3_level0_col11" class="col_heading level0 col11" >L1_dcache_accesses</th>
#       <th id="T_a9ee3_level0_col12" class="col_heading level0 col12" >branches</th>
#       <th id="T_a9ee3_level0_col13" class="col_heading level0 col13" >branch_misses</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a9ee3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a9ee3_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_a9ee3_row0_col1" class="data row0 col1" >131072</td>
#       <td id="T_a9ee3_row0_col2" class="data row0 col2" >1000</td>
#       <td id="T_a9ee3_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_a9ee3_row0_col4" class="data row0 col4" >1509679743</td>
#       <td id="T_a9ee3_row0_col5" class="data row0 col5" >1526078874</td>
#       <td id="T_a9ee3_row0_col6" class="data row0 col6" >1.010863</td>
#       <td id="T_a9ee3_row0_col7" class="data row0 col7" >0.179295</td>
#       <td id="T_a9ee3_row0_col8" class="data row0 col8" >0.273619</td>
#       <td id="T_a9ee3_row0_col9" class="data row0 col9" >0.001649</td>
#       <td id="T_a9ee3_row0_col10" class="data row0 col10" >1944116</td>
#       <td id="T_a9ee3_row0_col11" class="data row0 col11" >1178821893</td>
#       <td id="T_a9ee3_row0_col12" class="data row0 col12" >262739750</td>
#       <td id="T_a9ee3_row0_col13" class="data row0 col13" >35193548</td>
#     </tr>
#     <tr>
#       <th id="T_a9ee3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a9ee3_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_a9ee3_row1_col1" class="data row1 col1" >131072</td>
#       <td id="T_a9ee3_row1_col2" class="data row1 col2" >1000</td>
#       <td id="T_a9ee3_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_a9ee3_row1_col4" class="data row1 col4" >1522725405</td>
#       <td id="T_a9ee3_row1_col5" class="data row1 col5" >365287283</td>
#       <td id="T_a9ee3_row1_col6" class="data row1 col6" >0.239890</td>
#       <td id="T_a9ee3_row1_col7" class="data row1 col7" >0.179431</td>
#       <td id="T_a9ee3_row1_col8" class="data row1 col8" >0.065544</td>
#       <td id="T_a9ee3_row1_col9" class="data row1 col9" >0.002019</td>
#       <td id="T_a9ee3_row1_col10" class="data row1 col10" >2387354</td>
#       <td id="T_a9ee3_row1_col11" class="data row1 col11" >1182574195</td>
#       <td id="T_a9ee3_row1_col12" class="data row1 col12" >266035194</td>
#       <td id="T_a9ee3_row1_col13" class="data row1 col13" >962758</td>
#     </tr>
#   </tbody>
# </table>

# %%
miss_predictions_diff = (35193548-962758)
cycles_diff = 1526078874-365287283
cycles_diff/miss_predictions_diff
# Out:
# 33.91074500471652

# %% [markdown]
# What did we learn?
#
# The CPI is ??? smaller with data sorted (including sorting itself)
#
# The ET is ??? faster with data sorted (including sorting itself)
#
# What's the cost of branch misses?
#
# Let's exclude the sorting part and do it again.

# %%
! make clean; make
! sleep 2
! echo "size,iterations,sorted,IC,Cycles,CPI,CT,ET,L1_dcache_miss_rate,L1_dcache_misses,L1_dcache_accesses,branches,branch_misses" > stats.csv
! echo -n "262144,1000,0," >> stats.csv
! ./arraySort 262144 10000 0
! echo -n "262144,1000,1," >> stats.csv
! ./arraySort 262144 10000 1
display_df_mono(render_csv("stats.csv"))
# Out:
# rm -f madd arraySort *.o
# gcc -g -DHAVE_LINUX_PERF_EVENT_H -O0  -I/nfshome/htseng/courses/CS203/demo/branch  -o calculate_sum.o -c calculate_sum.c
# gcc -g -DHAVE_LINUX_PERF_EVENT_H -O3  -I/nfshome/htseng/courses/CS203/demo/branch  -o perfstats.o -c perfstats.c
# perfstats.c: In function ‘change_cpufrequnecy’:
# perfstats.c:115:11: warning: implicit declaration of function ‘sched_getcpu’; did you mean ‘SYS_getcpu’? [-Wimplicit-function-declaration]
#   115 |     cpu = sched_getcpu();
#       |           ^~~~~~~~~~~~
#       |           SYS_getcpu
# g++ -O3 -DHAVE_LINUX_PERF_EVENT_H  arraySort.cpp perfstats.o calculate_sum.o -o arraySort
# arraySort.cpp: In function ‘int main(int, char**)’:
# arraySort.cpp:53:22: warning: zero-length gnu_printf format string [-Wformat-zero-length]
#    53 |     sprintf(preamble,"");
#       |                      ^~
# g++ -g -DHAVE_LINUX_PERF_EVENT_H -O0  -I/nfshome/htseng/courses/CS203/demo/branch  -o bst.o -c bst.cpp
# g++ -O3 -DHAVE_LINUX_PERF_EVENT_H  bstSearch.cpp perfstats.o bst.o -o bstSearch
# bstSearch.cpp: In function ‘int main(int, char**)’:
# bstSearch.cpp:54:22: warning: zero-length gnu_printf format string [-Wformat-zero-length]
#    54 |     sprintf(preamble,"");
#       |                      ^~
# sum = 1311184316
# sum = 1311184316
# <style type="text/css">
# #T_d565d_row0_col0, #T_d565d_row0_col1, #T_d565d_row0_col2, #T_d565d_row0_col3, #T_d565d_row0_col4, #T_d565d_row0_col5, #T_d565d_row0_col6, #T_d565d_row0_col7, #T_d565d_row0_col8, #T_d565d_row0_col9, #T_d565d_row0_col10, #T_d565d_row0_col11, #T_d565d_row0_col12, #T_d565d_row0_col13, #T_d565d_row1_col0, #T_d565d_row1_col1, #T_d565d_row1_col2, #T_d565d_row1_col3, #T_d565d_row1_col4, #T_d565d_row1_col5, #T_d565d_row1_col6, #T_d565d_row1_col7, #T_d565d_row1_col8, #T_d565d_row1_col9, #T_d565d_row1_col10, #T_d565d_row1_col11, #T_d565d_row1_col12, #T_d565d_row1_col13 {
#   font-family: SF Mono;
#   font-size: 1.4vw;
# }
# </style>
# <table id="T_d565d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d565d_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_d565d_level0_col1" class="col_heading level0 col1" >size</th>
#       <th id="T_d565d_level0_col2" class="col_heading level0 col2" >iterations</th>
#       <th id="T_d565d_level0_col3" class="col_heading level0 col3" >sorted</th>
#       <th id="T_d565d_level0_col4" class="col_heading level0 col4" >IC</th>
#       <th id="T_d565d_level0_col5" class="col_heading level0 col5" >Cycles</th>
#       <th id="T_d565d_level0_col6" class="col_heading level0 col6" >CPI</th>
#       <th id="T_d565d_level0_col7" class="col_heading level0 col7" >CT</th>
#       <th id="T_d565d_level0_col8" class="col_heading level0 col8" >ET</th>
#       <th id="T_d565d_level0_col9" class="col_heading level0 col9" >L1_dcache_miss_rate</th>
#       <th id="T_d565d_level0_col10" class="col_heading level0 col10" >L1_dcache_misses</th>
#       <th id="T_d565d_level0_col11" class="col_heading level0 col11" >L1_dcache_accesses</th>
#       <th id="T_d565d_level0_col12" class="col_heading level0 col12" >branches</th>
#       <th id="T_d565d_level0_col13" class="col_heading level0 col13" >branch_misses</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d565d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d565d_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_d565d_row0_col1" class="data row0 col1" >262144</td>
#       <td id="T_d565d_row0_col2" class="data row0 col2" >1000</td>
#       <td id="T_d565d_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_d565d_row0_col4" class="data row0 col4" >30211944185</td>
#       <td id="T_d565d_row0_col5" class="data row0 col5" >30354275854</td>
#       <td id="T_d565d_row0_col6" class="data row0 col6" >1.004711</td>
#       <td id="T_d565d_row0_col7" class="data row0 col7" >0.179328</td>
#       <td id="T_d565d_row0_col8" class="data row0 col8" >5.443376</td>
#       <td id="T_d565d_row0_col9" class="data row0 col9" >0.001409</td>
#       <td id="T_d565d_row0_col10" class="data row0 col10" >33289024</td>
#       <td id="T_d565d_row0_col11" class="data row0 col11" >23617839741</td>
#       <td id="T_d565d_row0_col12" class="data row0 col12" >5254231874</td>
#       <td id="T_d565d_row0_col13" class="data row0 col13" >693976097</td>
#     </tr>
#     <tr>
#       <th id="T_d565d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d565d_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_d565d_row1_col1" class="data row1 col1" >262144</td>
#       <td id="T_d565d_row1_col2" class="data row1 col2" >1000</td>
#       <td id="T_d565d_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_d565d_row1_col4" class="data row1 col4" >30162118030</td>
#       <td id="T_d565d_row1_col5" class="data row1 col5" >6876129483</td>
#       <td id="T_d565d_row1_col6" class="data row1 col6" >0.227972</td>
#       <td id="T_d565d_row1_col7" class="data row1 col7" >0.179622</td>
#       <td id="T_d565d_row1_col8" class="data row1 col8" >1.235103</td>
#       <td id="T_d565d_row1_col9" class="data row1 col9" >0.001187</td>
#       <td id="T_d565d_row1_col10" class="data row1 col10" >28019353</td>
#       <td id="T_d565d_row1_col11" class="data row1 col11" >23599579307</td>
#       <td id="T_d565d_row1_col12" class="data row1 col12" >5245555505</td>
#       <td id="T_d565d_row1_col13" class="data row1 col13" >32229</td>
#     </tr>
#   </tbody>
# </table>

# %%
Diff_Misses = 693976097-32229
Diff_Cycles = 30354275854-6876129483
print(Diff_Cycles/Diff_Misses)
# Out:
# 33.83291855963197

# %% [markdown]
# Let's try a different processor!

# %%
! make clean; make
! sleep 2
! echo "size,iterations,sorted,IC,Cycles,CPI,CT,ET,L1_dcache_miss_rate,L1_dcache_misses,L1_dcache_accesses,branches,branch_misses" > stats.csv
! ssh htseng@blissey 'make -C /nfshome/htseng/courses/CSE142/demo/branch/ clean all ; lscpu|grep "Model name"'
! echo -n "262144,1000,0," >> stats.csv
! ssh htseng@blissey "cd /nfshome/htseng/courses/CSE142/demo/branch; ./arraySort 262144 1000 0"
! echo -n "262144,1000,1," >> stats.csv
! ssh htseng@blissey "cd /nfshome/htseng/courses/CSE142/demo/branch; ./arraySort 262144 1000 1"
display_df_mono(render_csv("stats.csv"))
# Out:
# rm -f madd arraySort *.o
# gcc -g -DHAVE_LINUX_PERF_EVENT_H -O0  -I/nfshome/htseng/courses/CS203/demo/branch  -o calculate_sum.o -c calculate_sum.c
# gcc -g -DHAVE_LINUX_PERF_EVENT_H -O3  -I/nfshome/htseng/courses/CS203/demo/branch  -o perfstats.o -c perfstats.c
# perfstats.c: In function ‘change_cpufrequnecy’:
# perfstats.c:115:11: warning: implicit declaration of function ‘sched_getcpu’; did you mean ‘SYS_getcpu’? [-Wimplicit-function-declaration]
#   115 |     cpu = sched_getcpu();
#       |           ^~~~~~~~~~~~
#       |           SYS_getcpu
# g++ -O3 -DHAVE_LINUX_PERF_EVENT_H  arraySort.cpp perfstats.o calculate_sum.o -o arraySort
# arraySort.cpp: In function ‘int main(int, char**)’:
# arraySort.cpp:53:22: warning: zero-length gnu_printf format string [-Wformat-zero-length]
#    53 |     sprintf(preamble,"");
#       |                      ^~
# make: Entering directory '/nfshome/htseng/courses/CSE142/demo/branch'
# rm -f madd arraySort *.o
# gcc -g -DHAVE_LINUX_PERF_EVENT_H -O0  -I/nfshome/htseng  -o calculate_sum.o -c calculate_sum.c
# gcc -g -DHAVE_LINUX_PERF_EVENT_H -O3  -I/nfshome/htseng  -o perfstats.o -c perfstats.c
# perfstats.c: In function ‘change_cpufrequnecy’:
# perfstats.c:115:11: warning: implicit declaration of function ‘sched_getcpu’; did you mean ‘SYS_getcpu’? [-Wimplicit-function-declaration]
#   115 |     cpu = sched_getcpu();
#       |           ^~~~~~~~~~~~
#       |           SYS_getcpu
# g++ -O3 -DHAVE_LINUX_PERF_EVENT_H  arraySort.cpp perfstats.o calculate_sum.o -o arraySort
# arraySort.cpp: In function ‘int main(int, char**)’:
# arraySort.cpp:53:22: warning: zero-length gnu_printf format string [-Wformat-zero-length]
#    53 |     sprintf(preamble,"");
#       |                      ^~
# make: Leaving directory '/nfshome/htseng/courses/CSE142/demo/branch'
# Model name:                           AMD Ryzen 7 5700X 8-Core Processor
# sum = 127161197
# sum = 127161197
# <style type="text/css">
# #T_69134_row0_col0, #T_69134_row0_col1, #T_69134_row0_col2, #T_69134_row0_col3, #T_69134_row0_col4, #T_69134_row0_col5, #T_69134_row0_col6, #T_69134_row0_col7, #T_69134_row0_col8, #T_69134_row0_col9, #T_69134_row0_col10, #T_69134_row0_col11, #T_69134_row0_col12, #T_69134_row0_col13 {
#   font-family: SF Mono;
#   font-size: 1.4vw;
# }
# </style>
# <table id="T_69134">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_69134_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_69134_level0_col1" class="col_heading level0 col1" >size</th>
#       <th id="T_69134_level0_col2" class="col_heading level0 col2" >iterations</th>
#       <th id="T_69134_level0_col3" class="col_heading level0 col3" >sorted</th>
#       <th id="T_69134_level0_col4" class="col_heading level0 col4" >IC</th>
#       <th id="T_69134_level0_col5" class="col_heading level0 col5" >Cycles</th>
#       <th id="T_69134_level0_col6" class="col_heading level0 col6" >CPI</th>
#       <th id="T_69134_level0_col7" class="col_heading level0 col7" >CT</th>
#       <th id="T_69134_level0_col8" class="col_heading level0 col8" >ET</th>
#       <th id="T_69134_level0_col9" class="col_heading level0 col9" >L1_dcache_miss_rate</th>
#       <th id="T_69134_level0_col10" class="col_heading level0 col10" >L1_dcache_misses</th>
#       <th id="T_69134_level0_col11" class="col_heading level0 col11" >L1_dcache_accesses</th>
#       <th id="T_69134_level0_col12" class="col_heading level0 col12" >branches</th>
#       <th id="T_69134_level0_col13" class="col_heading level0 col13" >branch_misses</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_69134_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_69134_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_69134_row0_col1" class="data row0 col1" >262144</td>
#       <td id="T_69134_row0_col2" class="data row0 col2" >1000</td>
#       <td id="T_69134_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_69134_row0_col4" class="data row0 col4" >262144</td>
#       <td id="T_69134_row0_col5" class="data row0 col5" >1000</td>
#       <td id="T_69134_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_69134_row0_col7" class="data row0 col7" >nan</td>
#       <td id="T_69134_row0_col8" class="data row0 col8" >nan</td>
#       <td id="T_69134_row0_col9" class="data row0 col9" >nan</td>
#       <td id="T_69134_row0_col10" class="data row0 col10" >nan</td>
#       <td id="T_69134_row0_col11" class="data row0 col11" >nan</td>
#       <td id="T_69134_row0_col12" class="data row0 col12" >nan</td>
#       <td id="T_69134_row0_col13" class="data row0 col13" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %%
Diff_Misses = 49159652-57646
Diff_Cycles = 1941551579-789330059
print(Diff_Cycles/Diff_Misses)
# Out:
# 23.46587469359195

# %%
new_CPI = 0.9*1+0.1*24
print(new_CPI)
# Out:
# 3.3000000000000003

# %%
! make clean; make EXTRA_OPTS=-O3; sleep 2
#! echo "size,iterations,sorted,IC,Cycles,CPI,CT,ET,L1_dcache_miss_rate,L1_dcache_misses,L1_dcache_accesses,branches,branch_misses" > stats.csv
! echo -n "131072,1000,2," >> stats.csv
! ./bstSearch 131072 1000 1
#! echo -n "131072,1000,1," >> stats.csv
#! ./bstSearch 131072 1000 1
# Out:
# rm -f madd arraySort *.o
# gcc -g -DHAVE_LINUX_PERF_EVENT_H -O0 -O3 -I/nfshome/htseng/courses/CS203/demo/branch  -o calculate_sum.o -c calculate_sum.c
# gcc -g -DHAVE_LINUX_PERF_EVENT_H -O3 -O3 -I/nfshome/htseng/courses/CS203/demo/branch  -o perfstats.o -c perfstats.c
# perfstats.c: In function ‘change_cpufrequnecy’:
# perfstats.c:115:11: warning: implicit declaration of function ‘sched_getcpu’; did you mean ‘SYS_getcpu’? [-Wimplicit-function-declaration]
#   115 |     cpu = sched_getcpu();
#       |           ^~~~~~~~~~~~
#       |           SYS_getcpu
# g++ -O3 -DHAVE_LINUX_PERF_EVENT_H -O3 arraySort.cpp perfstats.o calculate_sum.o -o arraySort
# arraySort.cpp: In function ‘int main(int, char**)’:
# arraySort.cpp:53:22: warning: zero-length gnu_printf format string [-Wformat-zero-length]
#    53 |     sprintf(preamble,"");
#       |                      ^~
# g++ -g -DHAVE_LINUX_PERF_EVENT_H -O0 -O3 -I/nfshome/htseng/courses/CS203/demo/branch  -o bst.o -c bst.cpp
# g++ -O3 -DHAVE_LINUX_PERF_EVENT_H -O3 bstSearch.cpp perfstats.o bst.o -o bstSearch
# bstSearch.cpp: In function ‘int main(int, char**)’:
# bstSearch.cpp:31:20: error: cannot convert ‘Node*’ to ‘Node**’
#    31 |         insertNode(root, (int64_t)std::rand());
#       |                    ^~~~
#       |                    |
#       |                    Node*
# In file included from bstSearch.cpp:5:
# bst.h:14:24: note:   initializing argument 1 of ‘void insertNode(Node**, int64_t)’
#    14 | void insertNode(Node** root, int64_t data);
#       |                 ~~~~~~~^~~~
# bstSearch.cpp:54:22: warning: zero-length gnu_printf format string [-Wformat-zero-length]
#    54 |     sprintf(preamble,"");
#       |                      ^~
# make: *** [Makefile:16: bstSearch] Error 1
# /bin/bash: line 1: ./bstSearch: No such file or directory

# %%
display_df_mono(render_csv("stats.csv"))
# Out:
# <style type="text/css">
# #T_c901b_row0_col0, #T_c901b_row0_col1, #T_c901b_row0_col2, #T_c901b_row0_col3, #T_c901b_row0_col4, #T_c901b_row0_col5, #T_c901b_row0_col6, #T_c901b_row0_col7, #T_c901b_row0_col8, #T_c901b_row0_col9, #T_c901b_row0_col10, #T_c901b_row0_col11, #T_c901b_row0_col12, #T_c901b_row0_col13, #T_c901b_row1_col0, #T_c901b_row1_col1, #T_c901b_row1_col2, #T_c901b_row1_col3, #T_c901b_row1_col4, #T_c901b_row1_col5, #T_c901b_row1_col6, #T_c901b_row1_col7, #T_c901b_row1_col8, #T_c901b_row1_col9, #T_c901b_row1_col10, #T_c901b_row1_col11, #T_c901b_row1_col12, #T_c901b_row1_col13, #T_c901b_row2_col0, #T_c901b_row2_col1, #T_c901b_row2_col2, #T_c901b_row2_col3, #T_c901b_row2_col4, #T_c901b_row2_col5, #T_c901b_row2_col6, #T_c901b_row2_col7, #T_c901b_row2_col8, #T_c901b_row2_col9, #T_c901b_row2_col10, #T_c901b_row2_col11, #T_c901b_row2_col12, #T_c901b_row2_col13 {
#   font-family: SF Mono;
#   font-size: 1.4vw;
# }
# </style>
# <table id="T_c901b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c901b_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_c901b_level0_col1" class="col_heading level0 col1" >size</th>
#       <th id="T_c901b_level0_col2" class="col_heading level0 col2" >iterations</th>
#       <th id="T_c901b_level0_col3" class="col_heading level0 col3" >sorted</th>
#       <th id="T_c901b_level0_col4" class="col_heading level0 col4" >IC</th>
#       <th id="T_c901b_level0_col5" class="col_heading level0 col5" >Cycles</th>
#       <th id="T_c901b_level0_col6" class="col_heading level0 col6" >CPI</th>
#       <th id="T_c901b_level0_col7" class="col_heading level0 col7" >CT</th>
#       <th id="T_c901b_level0_col8" class="col_heading level0 col8" >ET</th>
#       <th id="T_c901b_level0_col9" class="col_heading level0 col9" >L1_dcache_miss_rate</th>
#       <th id="T_c901b_level0_col10" class="col_heading level0 col10" >L1_dcache_misses</th>
#       <th id="T_c901b_level0_col11" class="col_heading level0 col11" >L1_dcache_accesses</th>
#       <th id="T_c901b_level0_col12" class="col_heading level0 col12" >branches</th>
#       <th id="T_c901b_level0_col13" class="col_heading level0 col13" >branch_misses</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c901b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c901b_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_c901b_row0_col1" class="data row0 col1" >131072</td>
#       <td id="T_c901b_row0_col2" class="data row0 col2" >1000</td>
#       <td id="T_c901b_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_c901b_row0_col4" class="data row0 col4" >1509863524</td>
#       <td id="T_c901b_row0_col5" class="data row0 col5" >1549902264</td>
#       <td id="T_c901b_row0_col6" class="data row0 col6" >1.026518</td>
#       <td id="T_c901b_row0_col7" class="data row0 col7" >0.202682</td>
#       <td id="T_c901b_row0_col8" class="data row0 col8" >0.314137</td>
#       <td id="T_c901b_row0_col9" class="data row0 col9" >0.003936</td>
#       <td id="T_c901b_row0_col10" class="data row0 col10" >4640716</td>
#       <td id="T_c901b_row0_col11" class="data row0 col11" >1178910227</td>
#       <td id="T_c901b_row0_col12" class="data row0 col12" >262765964</td>
#       <td id="T_c901b_row0_col13" class="data row0 col13" >35334854</td>
#     </tr>
#     <tr>
#       <th id="T_c901b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c901b_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_c901b_row1_col1" class="data row1 col1" >131072</td>
#       <td id="T_c901b_row1_col2" class="data row1 col2" >1000</td>
#       <td id="T_c901b_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_c901b_row1_col4" class="data row1 col4" >1522994340</td>
#       <td id="T_c901b_row1_col5" class="data row1 col5" >378758637</td>
#       <td id="T_c901b_row1_col6" class="data row1 col6" >0.248693</td>
#       <td id="T_c901b_row1_col7" class="data row1 col7" >0.195570</td>
#       <td id="T_c901b_row1_col8" class="data row1 col8" >0.074074</td>
#       <td id="T_c901b_row1_col9" class="data row1 col9" >0.006281</td>
#       <td id="T_c901b_row1_col10" class="data row1 col10" >7428313</td>
#       <td id="T_c901b_row1_col11" class="data row1 col11" >1182686456</td>
#       <td id="T_c901b_row1_col12" class="data row1 col12" >266077862</td>
#       <td id="T_c901b_row1_col13" class="data row1 col13" >963615</td>
#     </tr>
#     <tr>
#       <th id="T_c901b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c901b_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_c901b_row2_col1" class="data row2 col1" >131072</td>
#       <td id="T_c901b_row2_col2" class="data row2 col2" >1000</td>
#       <td id="T_c901b_row2_col3" class="data row2 col3" >2</td>
#       <td id="T_c901b_row2_col4" class="data row2 col4" >1968171657</td>
#       <td id="T_c901b_row2_col5" class="data row2 col5" >460758914</td>
#       <td id="T_c901b_row2_col6" class="data row2 col6" >0.234105</td>
#       <td id="T_c901b_row2_col7" class="data row2 col7" >0.192836</td>
#       <td id="T_c901b_row2_col8" class="data row2 col8" >0.088851</td>
#       <td id="T_c901b_row2_col9" class="data row2 col9" >0.111585</td>
#       <td id="T_c901b_row2_col10" class="data row2 col10" >73230012</td>
#       <td id="T_c901b_row2_col11" class="data row2 col11" >656273699</td>
#       <td id="T_c901b_row2_col12" class="data row2 col12" >524735930</td>
#       <td id="T_c901b_row2_col13" class="data row2 col13" >4080</td>
#     </tr>
#   </tbody>
# </table>

# %%
! make clean; make
! sleep 2
! echo "size,iterations,sorted,IC,Cycles,CPI,CT,ET,L1_dcache_miss_rate,L1_dcache_misses,L1_dcache_accesses,branches,branch_misses" > stats.csv
! echo -n "131072,2000,0," >> stats.csv
! ./arraySort 131072 2000 0
! echo -n "131072,2000,1," >> stats.csv
! ./arraySort 131072 2000 1
! echo -n "131072,2000,2," >> stats.csv
! ./bstSearch 131072 2000 1
! echo -n "131072,8000,0," >> stats.csv
! ./arraySort 131072 8000 0
! echo -n "131072,8000,1," >> stats.csv
! ./arraySort 131072 8000 1
! echo -n "131072,8000,2," >> stats.csv
! ./bstSearch 131072 8000 1
! echo -n "262144,8000,0," >> stats.csv
! ./arraySort 131072 8000 0
! echo -n "262144,8000,1," >> stats.csv
! ./arraySort 131072 8000 1
! echo -n "262144,8000,2," >> stats.csv
! ./bstSearch 131072 8000 1
display_df_mono(render_csv("stats.csv"))
# Out:
# rm -f madd arraySort *.o
# gcc -g -DHAVE_LINUX_PERF_EVENT_H -O0  -I/nfshome/htseng/courses/CS203/demo/branch  -o calculate_sum.o -c calculate_sum.c
# gcc -g -DHAVE_LINUX_PERF_EVENT_H -O3  -I/nfshome/htseng/courses/CS203/demo/branch  -o perfstats.o -c perfstats.c
# perfstats.c: In function ‘change_cpufrequnecy’:
# perfstats.c:115:11: warning: implicit declaration of function ‘sched_getcpu’; did you mean ‘SYS_getcpu’? [-Wimplicit-function-declaration]
#   115 |     cpu = sched_getcpu();
#       |           ^~~~~~~~~~~~
#       |           SYS_getcpu
# g++ -O3 -DHAVE_LINUX_PERF_EVENT_H  arraySort.cpp perfstats.o calculate_sum.o -o arraySort
# arraySort.cpp: In function ‘int main(int, char**)’:
# arraySort.cpp:53:22: warning: zero-length gnu_printf format string [-Wformat-zero-length]
#    53 |     sprintf(preamble,"");
#       |                      ^~
# gcc -g -DHAVE_LINUX_PERF_EVENT_H -O0  -I/nfshome/htseng/courses/CS203/demo/branch  -o bst.o -c bst.c
# g++ -O3 -DHAVE_LINUX_PERF_EVENT_H  bstSearch.cpp perfstats.o bst.o -o bstSearch
# bstSearch.cpp: In function ‘int main(int, char**)’:
# bstSearch.cpp:54:22: warning: zero-length gnu_printf format string [-Wformat-zero-length]
#    54 |     sprintf(preamble,"");
#       |                      ^~
# sum = 129974003
# sum = 129974003
# sum = 0
# sum = 523045937
# sum = 523045937
# sum = 0
# sum = 523045937
# sum = 523045937
# sum = 0
# <style type="text/css">
# #T_edff7_row0_col0, #T_edff7_row0_col1, #T_edff7_row0_col2, #T_edff7_row0_col3, #T_edff7_row0_col4, #T_edff7_row0_col5, #T_edff7_row0_col6, #T_edff7_row0_col7, #T_edff7_row0_col8, #T_edff7_row0_col9, #T_edff7_row0_col10, #T_edff7_row0_col11, #T_edff7_row0_col12, #T_edff7_row0_col13, #T_edff7_row1_col0, #T_edff7_row1_col1, #T_edff7_row1_col2, #T_edff7_row1_col3, #T_edff7_row1_col4, #T_edff7_row1_col5, #T_edff7_row1_col6, #T_edff7_row1_col7, #T_edff7_row1_col8, #T_edff7_row1_col9, #T_edff7_row1_col10, #T_edff7_row1_col11, #T_edff7_row1_col12, #T_edff7_row1_col13, #T_edff7_row2_col0, #T_edff7_row2_col1, #T_edff7_row2_col2, #T_edff7_row2_col3, #T_edff7_row2_col4, #T_edff7_row2_col5, #T_edff7_row2_col6, #T_edff7_row2_col7, #T_edff7_row2_col8, #T_edff7_row2_col9, #T_edff7_row2_col10, #T_edff7_row2_col11, #T_edff7_row2_col12, #T_edff7_row2_col13, #T_edff7_row3_col0, #T_edff7_row3_col1, #T_edff7_row3_col2, #T_edff7_row3_col3, #T_edff7_row3_col4, #T_edff7_row3_col5, #T_edff7_row3_col6, #T_edff7_row3_col7, #T_edff7_row3_col8, #T_edff7_row3_col9, #T_edff7_row3_col10, #T_edff7_row3_col11, #T_edff7_row3_col12, #T_edff7_row3_col13, #T_edff7_row4_col0, #T_edff7_row4_col1, #T_edff7_row4_col2, #T_edff7_row4_col3, #T_edff7_row4_col4, #T_edff7_row4_col5, #T_edff7_row4_col6, #T_edff7_row4_col7, #T_edff7_row4_col8, #T_edff7_row4_col9, #T_edff7_row4_col10, #T_edff7_row4_col11, #T_edff7_row4_col12, #T_edff7_row4_col13, #T_edff7_row5_col0, #T_edff7_row5_col1, #T_edff7_row5_col2, #T_edff7_row5_col3, #T_edff7_row5_col4, #T_edff7_row5_col5, #T_edff7_row5_col6, #T_edff7_row5_col7, #T_edff7_row5_col8, #T_edff7_row5_col9, #T_edff7_row5_col10, #T_edff7_row5_col11, #T_edff7_row5_col12, #T_edff7_row5_col13, #T_edff7_row6_col0, #T_edff7_row6_col1, #T_edff7_row6_col2, #T_edff7_row6_col3, #T_edff7_row6_col4, #T_edff7_row6_col5, #T_edff7_row6_col6, #T_edff7_row6_col7, #T_edff7_row6_col8, #T_edff7_row6_col9, #T_edff7_row6_col10, #T_edff7_row6_col11, #T_edff7_row6_col12, #T_edff7_row6_col13, #T_edff7_row7_col0, #T_edff7_row7_col1, #T_edff7_row7_col2, #T_edff7_row7_col3, #T_edff7_row7_col4, #T_edff7_row7_col5, #T_edff7_row7_col6, #T_edff7_row7_col7, #T_edff7_row7_col8, #T_edff7_row7_col9, #T_edff7_row7_col10, #T_edff7_row7_col11, #T_edff7_row7_col12, #T_edff7_row7_col13, #T_edff7_row8_col0, #T_edff7_row8_col1, #T_edff7_row8_col2, #T_edff7_row8_col3, #T_edff7_row8_col4, #T_edff7_row8_col5, #T_edff7_row8_col6, #T_edff7_row8_col7, #T_edff7_row8_col8, #T_edff7_row8_col9, #T_edff7_row8_col10, #T_edff7_row8_col11, #T_edff7_row8_col12, #T_edff7_row8_col13 {
#   font-family: SF Mono;
#   font-size: 1.4vw;
# }
# </style>
# <table id="T_edff7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_edff7_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_edff7_level0_col1" class="col_heading level0 col1" >size</th>
#       <th id="T_edff7_level0_col2" class="col_heading level0 col2" >iterations</th>
#       <th id="T_edff7_level0_col3" class="col_heading level0 col3" >sorted</th>
#       <th id="T_edff7_level0_col4" class="col_heading level0 col4" >IC</th>
#       <th id="T_edff7_level0_col5" class="col_heading level0 col5" >Cycles</th>
#       <th id="T_edff7_level0_col6" class="col_heading level0 col6" >CPI</th>
#       <th id="T_edff7_level0_col7" class="col_heading level0 col7" >CT</th>
#       <th id="T_edff7_level0_col8" class="col_heading level0 col8" >ET</th>
#       <th id="T_edff7_level0_col9" class="col_heading level0 col9" >L1_dcache_miss_rate</th>
#       <th id="T_edff7_level0_col10" class="col_heading level0 col10" >L1_dcache_misses</th>
#       <th id="T_edff7_level0_col11" class="col_heading level0 col11" >L1_dcache_accesses</th>
#       <th id="T_edff7_level0_col12" class="col_heading level0 col12" >branches</th>
#       <th id="T_edff7_level0_col13" class="col_heading level0 col13" >branch_misses</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_edff7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_edff7_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_edff7_row0_col1" class="data row0 col1" >131072</td>
#       <td id="T_edff7_row0_col2" class="data row0 col2" >2000</td>
#       <td id="T_edff7_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_edff7_row0_col4" class="data row0 col4" >2984770554</td>
#       <td id="T_edff7_row0_col5" class="data row0 col5" >3007203279</td>
#       <td id="T_edff7_row0_col6" class="data row0 col6" >1.007516</td>
#       <td id="T_edff7_row0_col7" class="data row0 col7" >0.201416</td>
#       <td id="T_edff7_row0_col8" class="data row0 col8" >0.605699</td>
#       <td id="T_edff7_row0_col9" class="data row0 col9" >0.001849</td>
#       <td id="T_edff7_row0_col10" class="data row0 col10" >4311738</td>
#       <td id="T_edff7_row0_col11" class="data row0 col11" >2331833932</td>
#       <td id="T_edff7_row0_col12" class="data row0 col12" >519227293</td>
#       <td id="T_edff7_row0_col13" class="data row0 col13" >68647965</td>
#     </tr>
#     <tr>
#       <th id="T_edff7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_edff7_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_edff7_row1_col1" class="data row1 col1" >131072</td>
#       <td id="T_edff7_row1_col2" class="data row1 col2" >2000</td>
#       <td id="T_edff7_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_edff7_row1_col4" class="data row1 col4" >3015204632</td>
#       <td id="T_edff7_row1_col5" class="data row1 col5" >698187494</td>
#       <td id="T_edff7_row1_col6" class="data row1 col6" >0.231556</td>
#       <td id="T_edff7_row1_col7" class="data row1 col7" >0.194408</td>
#       <td id="T_edff7_row1_col8" class="data row1 col8" >0.135733</td>
#       <td id="T_edff7_row1_col9" class="data row1 col9" >0.000844</td>
#       <td id="T_edff7_row1_col10" class="data row1 col10" >1988892</td>
#       <td id="T_edff7_row1_col11" class="data row1 col11" >2357737595</td>
#       <td id="T_edff7_row1_col12" class="data row1 col12" >524583833</td>
#       <td id="T_edff7_row1_col13" class="data row1 col13" >6356</td>
#     </tr>
#     <tr>
#       <th id="T_edff7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_edff7_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_edff7_row2_col1" class="data row2 col1" >131072</td>
#       <td id="T_edff7_row2_col2" class="data row2 col2" >2000</td>
#       <td id="T_edff7_row2_col3" class="data row2 col3" >2</td>
#       <td id="T_edff7_row2_col4" class="data row2 col4" >6823832406</td>
#       <td id="T_edff7_row2_col5" class="data row2 col5" >1744884131</td>
#       <td id="T_edff7_row2_col6" class="data row2 col6" >0.255704</td>
#       <td id="T_edff7_row2_col7" class="data row2 col7" >0.193966</td>
#       <td id="T_edff7_row2_col8" class="data row2 col8" >0.338449</td>
#       <td id="T_edff7_row2_col9" class="data row2 col9" >0.002207</td>
#       <td id="T_edff7_row2_col10" class="data row2 col10" >11578272</td>
#       <td id="T_edff7_row2_col11" class="data row2 col11" >5246442261</td>
#       <td id="T_edff7_row2_col12" class="data row2 col12" >1050300896</td>
#       <td id="T_edff7_row2_col13" class="data row2 col13" >11092</td>
#     </tr>
#     <tr>
#       <th id="T_edff7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_edff7_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_edff7_row3_col1" class="data row3 col1" >131072</td>
#       <td id="T_edff7_row3_col2" class="data row3 col2" >8000</td>
#       <td id="T_edff7_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_edff7_row3_col4" class="data row3 col4" >12071727068</td>
#       <td id="T_edff7_row3_col5" class="data row3 col5" >12237438812</td>
#       <td id="T_edff7_row3_col6" class="data row3 col6" >1.013727</td>
#       <td id="T_edff7_row3_col7" class="data row3 col7" >0.195507</td>
#       <td id="T_edff7_row3_col8" class="data row3 col8" >2.392503</td>
#       <td id="T_edff7_row3_col9" class="data row3 col9" >0.001563</td>
#       <td id="T_edff7_row3_col10" class="data row3 col10" >14748940</td
