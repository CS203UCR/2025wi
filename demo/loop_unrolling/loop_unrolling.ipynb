# %%
# %load_ext autoreload
# %autoreload 2
from notebook import *
# if get something about NUMEXPR_MAX_THREADS being set incorrectly, don't worry.  It's not a problem.
# Out:
# <style>h1 {font-size: 2vw;} h2 {font-size: 1.5vw;} p {font-size: 1.4vw;} div.prompt, code, output, prompt, kbd, pre, samp {font-family: 'SF Mono', 'Courier New', Courier, monospace, sans-serif !important;font-size: 1.4vw !important;}</style>

# %% [markdown]
# # Loop Unrolling

# %%
compare([do_render_code("swap.c", show="swap_array_1"),do_render_code("swap.c", show="swap_array_2")])
# Out:
#             <style>
#         .side-by-side {
#             display: flex;
#             align-items: stretch;
#         }
#         .side-by-side-pane {
#             margin-right:1em;
#             border-right-style: solid;
#             border-right-color: black;
#             border-right-width: 1px;
#             flex: 1;
#         }
#         </style>
#         <div class="side-by-side"> <div class='side-by-side-pane'><style>pre { line-height: 125%; }
# td.linenos .normal { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# .output_html .hll { background-color: #ffffcc }
# .output_html { background: #f8f8f8; }
# .output_html .c { color: #3D7B7B; font-style: italic } /* Comment */
# .output_html .err { border: 1px solid #FF0000 } /* Error */
# .output_html .k { color: #008000; font-weight: bold } /* Keyword */
# .output_html .o { color: #666666 } /* Operator */
# .output_html .ch { color: #3D7B7B; font-style: italic } /* Comment.Hashbang */
# .output_html .cm { color: #3D7B7B; font-style: italic } /* Comment.Multiline */
# .output_html .cp { color: #9C6500 } /* Comment.Preproc */
# .output_html .cpf { color: #3D7B7B; font-style: italic } /* Comment.PreprocFile */
# .output_html .c1 { color: #3D7B7B; font-style: italic } /* Comment.Single */
# .output_html .cs { color: #3D7B7B; font-style: italic } /* Comment.Special */
# .output_html .gd { color: #A00000 } /* Generic.Deleted */
# .output_html .ge { font-style: italic } /* Generic.Emph */
# .output_html .ges { font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# .output_html .gr { color: #E40000 } /* Generic.Error */
# .output_html .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .output_html .gi { color: #008400 } /* Generic.Inserted */
# .output_html .go { color: #717171 } /* Generic.Output */
# .output_html .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# .output_html .gs { font-weight: bold } /* Generic.Strong */
# .output_html .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .output_html .gt { color: #0044DD } /* Generic.Traceback */
# .output_html .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# .output_html .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# .output_html .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# .output_html .kp { color: #008000 } /* Keyword.Pseudo */
# .output_html .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# .output_html .kt { color: #B00040 } /* Keyword.Type */
# .output_html .m { color: #666666 } /* Literal.Number */
# .output_html .s { color: #BA2121 } /* Literal.String */
# .output_html .na { color: #687822 } /* Name.Attribute */
# .output_html .nb { color: #008000 } /* Name.Builtin */
# .output_html .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# .output_html .no { color: #880000 } /* Name.Constant */
# .output_html .nd { color: #AA22FF } /* Name.Decorator */
# .output_html .ni { color: #717171; font-weight: bold } /* Name.Entity */
# .output_html .ne { color: #CB3F38; font-weight: bold } /* Name.Exception */
# .output_html .nf { color: #0000FF } /* Name.Function */
# .output_html .nl { color: #767600 } /* Name.Label */
# .output_html .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# .output_html .nt { color: #008000; font-weight: bold } /* Name.Tag */
# .output_html .nv { color: #19177C } /* Name.Variable */
# .output_html .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# .output_html .w { color: #bbbbbb } /* Text.Whitespace */
# .output_html .mb { color: #666666 } /* Literal.Number.Bin */
# .output_html .mf { color: #666666 } /* Literal.Number.Float */
# .output_html .mh { color: #666666 } /* Literal.Number.Hex */
# .output_html .mi { color: #666666 } /* Literal.Number.Integer */
# .output_html .mo { color: #666666 } /* Literal.Number.Oct */
# .output_html .sa { color: #BA2121 } /* Literal.String.Affix */
# .output_html .sb { color: #BA2121 } /* Literal.String.Backtick */
# .output_html .sc { color: #BA2121 } /* Literal.String.Char */
# .output_html .dl { color: #BA2121 } /* Literal.String.Delimiter */
# .output_html .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# .output_html .s2 { color: #BA2121 } /* Literal.String.Double */
# .output_html .se { color: #AA5D1F; font-weight: bold } /* Literal.String.Escape */
# .output_html .sh { color: #BA2121 } /* Literal.String.Heredoc */
# .output_html .si { color: #A45A77; font-weight: bold } /* Literal.String.Interpol */
# .output_html .sx { color: #008000 } /* Literal.String.Other */
# .output_html .sr { color: #A45A77 } /* Literal.String.Regex */
# .output_html .s1 { color: #BA2121 } /* Literal.String.Single */
# .output_html .ss { color: #19177C } /* Literal.String.Symbol */
# .output_html .bp { color: #008000 } /* Name.Builtin.Pseudo */
# .output_html .fm { color: #0000FF } /* Name.Function.Magic */
# .output_html .vc { color: #19177C } /* Name.Variable.Class */
# .output_html .vg { color: #19177C } /* Name.Variable.Global */
# .output_html .vi { color: #19177C } /* Name.Variable.Instance */
# .output_html .vm { color: #19177C } /* Name.Variable.Magic */
# .output_html .il { color: #666666 } /* Literal.Number.Integer.Long */</style><div class="highlight"><pre><span></span><span class="c1">// swap.c:16-22 (7 lines)</span>
# <span class="kt">void</span><span class="w"> </span><span class="nf">swap_array_1</span><span class="p">(</span><span class="kt">uint64_t</span><span class="w"> </span><span class="o">*</span><span class="n">a</span><span class="p">,</span><span class="w"> </span><span class="kt">uint64_t</span><span class="w"> </span><span class="o">*</span><span class="n">b</span><span class="p">,</span><span class="w"> </span><span class="kt">uint64_t</span><span class="w"> </span><span class="n">size</span><span class="p">)</span>
# <span class="p">{</span>
# <span class="w">    </span><span class="k">for</span><span class="w"> </span><span class="p">(</span><span class="kt">uint64_t</span><span class="w"> </span><span class="n">i</span><span class="w"> </span><span class="o">=</span><span class="w"> </span><span class="mi">0</span><span class="p">;</span><span class="w"> </span><span class="n">i</span><span class="w"> </span><span class="o">&lt;</span><span class="w"> </span><span class="n">size</span><span class="p">;</span><span class="w"> </span><span class="o">++</span><span class="n">i</span><span class="p">)</span><span class="w"> </span><span class="p">{</span>
# <span class="w">        </span><span class="n">swap</span><span class="p">(</span><span class="o">&amp;</span><span class="n">a</span><span class="p">[</span><span class="n">i</span><span class="p">],</span><span class="o">&amp;</span><span class="n">b</span><span class="p">[</span><span class="n">i</span><span class="p">]);</span>
# <span class="w">    </span><span class="p">}</span>
#
# <span class="p">}</span>
# </pre></div>
# </div><div class='side-by-side-pane'><style>pre { line-height: 125%; }
# td.linenos .normal { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# .output_html .hll { background-color: #ffffcc }
# .output_html { background: #f8f8f8; }
# .output_html .c { color: #3D7B7B; font-style: italic } /* Comment */
# .output_html .err { border: 1px solid #FF0000 } /* Error */
# .output_html .k { color: #008000; font-weight: bold } /* Keyword */
# .output_html .o { color: #666666 } /* Operator */
# .output_html .ch { colo

# %%
! gcc -S -O3 swap.c
compare([do_render_code("swap.s",show=["swap_array_1:",".L1:"]),do_render_code("swap.s", show=["swap_array_2:","L20:"])])
#compare([do_render_code("swap.s",show=["swap_array_1:",".L1:"]),do_render_code("swap.s", show=["swap_array_2:","L20:"]),do_render_code("swap.s", show=["L36:","ret"])])
# Out:
# swap.c: In function ‘main’:
# swap.c:62:5: warning: implicit declaration of function ‘perfstats_init’ [-Wimplicit-function-declaration]
#    62 |     perfstats_init();
#       |     ^~~~~~~~~~~~~~
# swap.c:63:5: warning: implicit declaration of function ‘perfstats_enable’ [-Wimplicit-function-declaration]
#    63 |     perfstats_enable(1);
#       |     ^~~~~~~~~~~~~~~~
# swap.c:66:5: warning: implicit declaration of function ‘perfstats_disable’ [-Wimplicit-function-declaration]
#    66 |     perfstats_disable(1);
#       |     ^~~~~~~~~~~~~~~~~
# swap.c:67:5: warning: implicit declaration of function ‘perfstats_print’ [-Wimplicit-function-declaration]
#    67 |     perfstats_print();
#       |     ^~~~~~~~~~~~~~~
# swap.c:68:5: warning: implicit declaration of function ‘perfstats_deinit’ [-Wimplicit-function-declaration]
#    68 |     perfstats_deinit();
#       |     ^~~~~~~~~~~~~~~~
#             <style>
#         .side-by-side {
#             display: flex;
#             align-items: stretch;
#         }
#         .side-by-side-pane {
#             margin-right:1em;
#             border-right-style: solid;
#             border-right-color: black;
#             border-right-width: 1px;
#             flex: 1;
#         }
#         </style>
#         <div class="side-by-side"> <div class='side-by-side-pane'><style>pre { line-height: 125%; }
# td.linenos .normal { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# .output_html .hll { background-color: #ffffcc }
# .output_html { background: #f8f8f8; }
# .output_html .c { color: #3D7B7B; font-style: italic } /* Comment */
# .output_html .err { border: 1px solid #FF0000 } /* Error */
# .output_html .k { color: #008000; font-weight: bold } /* Keyword */
# .output_html .o { color: #666666 } /* Operator */
# .output_html .ch { color: #3D7B7B; font-style: italic } /* Comment.Hashbang */
# .output_html .cm { color: #3D7B7B; font-style: italic } /* Comment.Multiline */
# .output_html .cp { color: #9C6500 } /* Comment.Preproc */
# .output_html .cpf { color: #3D7B7B; font-style: italic } /* Comment.PreprocFile */
# .output_html .c1 { color: #3D7B7B; font-style: italic } /* Comment.Single */
# .output_html .cs { color: #3D7B7B; font-style: italic } /* Comment.Special */
# .output_html .gd { color: #A00000 } /* Generic.Deleted */
# .output_html .ge { font-style: italic } /* Generic.Emph */
# .output_html .ges { font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# .output_html .gr { color: #E40000 } /* Generic.Error */
# .output_html .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .output_html .gi { color: #008400 } /* Generic.Inserted */
# .output_html .go { color: #717171 } /* Generic.Output */
# .output_html .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# .output_html .gs { font-weight: bold } /* Generic.Strong */
# .output_html .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .output_html .gt { color: #0044DD } /* Generic.Traceback */
# .output_html .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# .output_html .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# .output_html .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# .output_html .kp { color: #008000 } /* Keyword.Pseudo */
# .output_html .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# .output_html .kt { color: #B00040 } /* Keyword.Type */
# .output_html .m { color: #666666 } /* Literal.Number */
# .output_html .s { color: #BA2121 } /* Literal.String */
# .output_html .na { color: #687822 } /* Name.Attribute */
# .output_html .nb { color: #008000 } /* Name.Builtin */
# .output_html .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# .output_html .no { color: #880000 } /* Name.Constant */
# .output_html .nd { color: #AA22FF } /* Name.Decorator */
# .output_html .ni { color: #717171; font-weight: bold } /* Name.Entity */
# .output_html .ne { color: #CB3F38; font-weight: bold } /* Name.Exception */
# .output_html .nf { color: #0000FF } /* Name.Function */
# .output_html .nl { color: #767600 } /* Name.Label */
# .output_html .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# .output_html .nt { color: #008000; font-weight: bold } /* Name.Tag */
# .output_html .nv { color: #19177C } /* Name.Variable */
# .output_html .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# .output_html .w { color: #bbbbbb } /* Text.Whitespace */
# .output_html .mb { color: #666666 } /* Literal.Number.Bin */
# .output_html .mf { color: #666666 } /* Literal.Number.Float */
# .output_html .mh { color: #666666 } /* Literal.Number.Hex */
# .output_html .mi { color: #666666 } /* Literal.Number.Integer */
# .output_html .mo { color: #666666 } /* Literal.Number.Oct */
# .output_html .sa { color: #BA2121 } /* Literal.String.Affix */
# .output_html .sb { color: #BA2121 } /* Literal.String.Backtick */
# .output_html .sc { color: #BA2121 } /* Literal.String.Char */
# .output_html .dl { color: #BA2121 } /* Literal.String.Delimiter */
# .output_html .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# .output_html .s2 { color: #BA2121 } /* Literal.String.Double */
# .output_html .se { color: #AA5D1F; font-weight: bold } /* Literal.String.Escape */
# .output_html .sh { color: #BA2121 } /* Literal.String.Heredoc */
# .output_html .si { color: #A45A77; font-weight: bold } /* Literal.String.Interpol */
# .output_html .sx { color: #008000 } /* Literal.String.Other */
# .output_html .sr { color: #A45A77 } /* Literal.String.Regex */
# .output_html .s1 { color: #BA2121 } /* Literal.String.Single */
# .output_html .ss { color: #19177C } /* Literal.String.Symbol */
# .output_html .bp { color: #008000 } /* Name.Builtin.Pseudo */
# .output_html .fm { color: #0000FF } /* Name.Function.Magic */
# .output_html .vc { color: #19177C } /* Name.Variable.Class */
# .output_html .vg { color: #19177C } /* Name.Variable.Global */
# .output_html .vi { color: #19177C } /* Name.Variable.Instance */
# .output_html .vm { color: #19177C } /* Name.Variable.Magic */
# .output_html .il { color: #666666 } /* Literal.Number.Integer.Long */</style><div class="highlight"><pre><span></span><span class="c1">// swap.s:6-32 (27 lines)</span>
# <span class="nl">swap_array_1</span><span class="p">:</span>
# <span class="p">.</span><span class="n">LFB40</span><span class="o">:</span>
# <span class="w">	</span><span class="p">.</span><span class="n">cfi_startproc</span>
# <span class="w">	</span><span class="n">endbr64</span>
# <span class="w">	</span><span class="n">movq</span><span class="w">	</span><span class="o">%</span><span class="n">rdi</span><span class="p">,</span><span class="w"> </span><span class="o">%</span><span class="n">r8</span>
# <span class="w">	</span><span class="n">movq</span><span class="w">	</span><span class="o">%</span><span class="n">rsi</span><span class="p">,</span><span class="w"> </span><span class="o">%</span><span class="n">rcx</span>
# <span class="w">	</span><span class="n">testq</span><span class="w">	</span><span class="o">%</span><span class="n">rdx</span><span class="p">,</span><span class="w"> </span><span class="o">%</span><span class="n">rdx</span>
# <span class="w">	</span><span class="n">je</span><span class="w">	</span><span class="p">.</span><span class="n">L1</span>
# <span class="w">	</span><span class="n">leaq</span><span class="w">	</span><span class="mi">-1</span><span class="p">(</span><span class="o">%</span><span class="n">rdx</span><span class="p">),</span><span class="w"> </span><span class="o">%</span><span class="n">rax</span>
# <span class="w">	</span><span class="n">cmpq</span><span class="w">	</span><span class="n">$1</span><span class="p">,</span><span class="w"> </span><span class="o">%</span><span class="n">rax</span>
# <span class="w">	</span><span class="n">jbe</span><span class="w">	</span><span class="p">.</span><span class="n">L8</span>
# <span class="w">	</span><span class="n">leaq</span><span class="w">	</span><span class="mi">15</span><span class="p">(</span><span class="o">%</span><span class="n">rsi</span><span class="p">),</span><span class="w"> </span><span class="o">%</span><span class="n">rsi</span>
# <span class="w">	</span><span class="n">xorl</span><span class="w">	</span><span class="o">%</span><span class="n">eax</span><span class="p">,</span><span class="w"> </span><span class="o">%</span><span class="n">eax</span>
# <span class="w">	</span><span class="n">subq</span><span class="w">	</span><span class="o">%</span><span class="n">rdi</span><span class="p">,</span><span class="w"> </span><span class="o">%</span><span class="n">rsi</span>
# <span class="w">	</span><span class="n">cmpq</span><sp

# %%
! make array_swap
! echo "size,iterations,unrolled?,IC,Cycles,CPI,CT,ET,L1_dcache_miss_rate,L1_dcache_misses,L1_dcache_accesses,branches,branch_misses" > stats.csv
! echo -n "262144,1000,0," >> stats.csv
! ./array_swap 262144 1000 0  2>> stats.csv
# Out:
# make: 'array_swap' is up to date.

# %%
! echo -n "262144,1000,1," >> stats.csv
! ./array_swap 262144 1000 1  2>> stats.csv

# %%
display_df_mono(render_csv("stats.csv"))
# Out:
# <style type="text/css">
# #T_80cba_row0_col0, #T_80cba_row0_col1, #T_80cba_row0_col2, #T_80cba_row0_col3, #T_80cba_row0_col4, #T_80cba_row0_col5, #T_80cba_row0_col6, #T_80cba_row0_col7, #T_80cba_row0_col8, #T_80cba_row0_col9, #T_80cba_row0_col10, #T_80cba_row0_col11, #T_80cba_row0_col12, #T_80cba_row0_col13, #T_80cba_row1_col0, #T_80cba_row1_col1, #T_80cba_row1_col2, #T_80cba_row1_col3, #T_80cba_row1_col4, #T_80cba_row1_col5, #T_80cba_row1_col6, #T_80cba_row1_col7, #T_80cba_row1_col8, #T_80cba_row1_col9, #T_80cba_row1_col10, #T_80cba_row1_col11, #T_80cba_row1_col12, #T_80cba_row1_col13 {
#   font-family: SF Mono;
#   font-size: 1.4vw;
# }
# </style>
# <table id="T_80cba">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_80cba_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_80cba_level0_col1" class="col_heading level0 col1" >size</th>
#       <th id="T_80cba_level0_col2" class="col_heading level0 col2" >iterations</th>
#       <th id="T_80cba_level0_col3" class="col_heading level0 col3" >unrolled?</th>
#       <th id="T_80cba_level0_col4" class="col_heading level0 col4" >IC</th>
#       <th id="T_80cba_level0_col5" class="col_heading level0 col5" >Cycles</th>
#       <th id="T_80cba_level0_col6" class="col_heading level0 col6" >CPI</th>
#       <th id="T_80cba_level0_col7" class="col_heading level0 col7" >CT</th>
#       <th id="T_80cba_level0_col8" class="col_heading level0 col8" >ET</th>
#       <th id="T_80cba_level0_col9" class="col_heading level0 col9" >L1_dcache_miss_rate</th>
#       <th id="T_80cba_level0_col10" class="col_heading level0 col10" >L1_dcache_misses</th>
#       <th id="T_80cba_level0_col11" class="col_heading level0 col11" >L1_dcache_accesses</th>
#       <th id="T_80cba_level0_col12" class="col_heading level0 col12" >branches</th>
#       <th id="T_80cba_level0_col13" class="col_heading level0 col13" >branch_misses</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_80cba_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_80cba_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_80cba_row0_col1" class="data row0 col1" >262144</td>
#       <td id="T_80cba_row0_col2" class="data row0 col2" >1000</td>
#       <td id="T_80cba_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_80cba_row0_col4" class="data row0 col4" >918457518</td>
#       <td id="T_80cba_row0_col5" class="data row0 col5" >453991152</td>
#       <td id="T_80cba_row0_col6" class="data row0 col6" >0.494297</td>
#       <td id="T_80cba_row0_col7" class="data row0 col7" >0.179874</td>
#       <td id="T_80cba_row0_col8" class="data row0 col8" >0.081661</td>
#       <td id="T_80cba_row0_col9" class="data row0 col9" >0.109405</td>
#       <td id="T_80cba_row0_col10" class="data row0 col10" >57397594</td>
#       <td id="T_80cba_row0_col11" class="data row0 col11" >524634405</td>
#       <td id="T_80cba_row0_col12" class="data row0 col12" >131239145</td>
#       <td id="T_80cba_row0_col13" class="data row0 col13" >2331</td>
#     </tr>
#     <tr>
#       <th id="T_80cba_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_80cba_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_80cba_row1_col1" class="data row1 col1" >262144</td>
#       <td id="T_80cba_row1_col2" class="data row1 col2" >1000</td>
#       <td id="T_80cba_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_80cba_row1_col4" class="data row1 col4" >1180825223</td>
#       <td id="T_80cba_row1_col5" class="data row1 col5" >543149882</td>
#       <td id="T_80cba_row1_col6" class="data row1 col6" >0.459975</td>
#       <td id="T_80cba_row1_col7" class="data row1 col7" >0.179606</td>
#       <td id="T_80cba_row1_col8" class="data row1 col8" >0.097553</td>
#       <td id="T_80cba_row1_col9" class="data row1 col9" >0.063937</td>
#       <td id="T_80cba_row1_col10" class="data row1 col10" >58689708</td>
#       <td id="T_80cba_row1_col11" class="data row1 col11" >917926794</td>
#       <td id="T_80cba_row1_col12" class="data row1 col12" >65742374</td>
#       <td id="T_80cba_row1_col13" class="data row1 col13" >2665</td>
#     </tr>
#   </tbody>
# </table>
